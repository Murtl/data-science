# %%
# %reload_kedro
# Out:
#                     INFO     Resolved project path as:                                              ]8;id=824719;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=954190;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro\ipython\__init__.py#178\178]8;;\
#                              C:\Users\michi\Repos\own\data-science\studentperfomance.
#                              To set a different path, run '%reload_kedro <project_root>'
# [12/05/24 08:03:31] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=424367;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=29338;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
# ...

# %%
print("Running data_interpretations pipeline...")
session.run("interpretations")
# Out:
# Running data_interpretations pipeline...
# [12/03/24 18:13:47] INFO     Kedro project studentperfomance                                         ]8;id=297046;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro\framework\session\session.py\session.py]8;;\:]8;id=721557;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro\framework\session\session.py#329\329]8;;\
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=643401;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=484093;file://C:\Users\michi\anaconda3\envs\autogluon-env\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
# ...

# %%
# %run_viz
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>

# %%
# check number 1 model
from autogluon.tabular import TabularPredictor

tabularPredictor = TabularPredictor.load(path=r"AutogluonModels\ag-20241201_160654")

# %%
tabularPredictor.leaderboard(extra_info=True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                       model  score_val eval_metric  pred_time_val  \
# 0       WeightedEnsemble_L3   0.871325    accuracy      80.234711
# 1           LightGBM_BAG_L2   0.871325    accuracy      80.234711
# 2   RandomForestGini_BAG_L2   0.868509    accuracy      79.247086
# 3           CatBoost_BAG_L2   0.867629    accuracy      77.460234
# 4   RandomForestEntr_BAG_L2   0.865693    accuracy      79.249064
# 5         LightGBMXT_BAG_L2   0.864813    accuracy      84.071469
# 6            XGBoost_BAG_L2   0.863228    accuracy      77.608157
# 7     ExtraTreesEntr_BAG_L2   0.858124    accuracy      78.968411
# 8     ExtraTreesGini_BAG_L2   0.856715    accuracy      79.131200
# 9       WeightedEnsemble_L2   0.844218    accuracy       0.943003
# 10   NeuralNetFastAI_BAG_L2   0.839817    accuracy      77.767030
# ...

# %%
ensemble_model = tabularPredictor._trainer.load_model("WeightedEnsemble_L3")
ensemble_model.get_info()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'name': 'WeightedEnsemble_L3',
#     'model_type': 'WeightedEnsembleModel',
#     'problem_type': 'multiclass',
#     'eval_metric': 'accuracy',
#     'stopping_metric': 'accuracy',
#     'fit_time': 3.1230037212371826,
#     'num_classes': 19,
#     'quantile_levels': None,
#     'predict_time': 0.0,
#     'val_score': 0.871325470867805,
#     'hyperparameters': {
#         'use_orig_features': False,
#         'max_base_models': 25,
#         'max_base_models_per_type': 5,
#         'save_bag_folds': True
#     },
#     'hyperparameters_fit': {},
#     'hyperparameters_nondefault': ['save_bag_folds'],
#     'ag_args_fit': {
#         'max_memory_usage_ratio': 1.0,
#         'max_time_limit_ratio': 1.0,
#         'max_time_limit': None,
#         'min_time_limit': 0,
#         'valid_raw_types': None,
# ...
